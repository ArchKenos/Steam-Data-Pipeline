# %%
import pandas as pd
from pathlib import Path

# %%
RAW_DIR = Path("data") / "raw" 
file_path = RAW_DIR / "steamspy_page0.json"
df = pd.read_json(file_path, orient='index')
df = df.reset_index(drop=True)
df = df.drop(columns=['score_rank', 'userscore', 'average_forever', 'average_2weeks', 'median_forever', 'median_2weeks'])

# %%
df.head()
# Out:
#      appid                              name         developer  \
# 0      730  Counter-Strike: Global Offensive             Valve
# 1  1172470                      Apex Legends           Respawn
# 2   578080               PUBG: BATTLEGROUNDS  PUBG Corporation
# 3  1623730                          Palworld        Pocketpair
# 4      440                   Team Fortress 2             Valve
#
#          publisher  positive  negative                      owners  price  \
# 0            Valve   7642084   1173003  100,000,000 .. 200,000,000      0
# 1  Electronic Arts    668053    326926  100,000,000 .. 200,000,000      0
# 2    KRAFTON, Inc.   1520457   1037487  100,000,000 .. 200,000,000      0
# 3       Pocketpair    358266     22443   50,000,000 .. 100,000,000   2999
# 4            Valve   1044264    117208   50,000,000 .. 100,000,000      0
#
#    initialprice  discount      ccu
# 0             0         0  1013936
# 1             0         0   124262
# ...
